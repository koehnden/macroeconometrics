# %% [markdown]
# # Identifying Shocks
# This Notebook can be found and more convieniently viewed under https://github.com/koehnden/macroeconometrics/blob/master/svar/ in Problem Set 2.ipynb. Furthermore, related Python scripts can be found in the same directory in this repo. If you have Python installed you can also clone the repo and play around with the code. Most convienient way to get python through anaconda (see https://anaconda.org/anaconda/python). It should come with all the relevant libraries and sofware to use jupyter notebooks.

# %%
# import relevant libraries
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import os
from preprocessing import *

# %% [markdown]
# ### Proprocessing and joining
# Using the function from helper.py script, we join the 4 data sets into one data frame based on common time index. Before doing that we preprocess the data. Inflation needs to be computed as the growth rate of the Consumer Price Index (CPI). Furthermore, we take the log of GDP and M2. Since some data were only available monthly, we need to convert them. For GDP and M2 and

# %%
# load data 
path = 'data/'
gdp = pd.read_csv(path +'RealGDPPerCapita.csv')
m2 = pd.read_csv(path + 'M2Real.csv')
fed_funds = pd.read_csv(path + 'fedFundsRate.csv')
inflation = pd.read_csv(path + 'Inflation.csv')         

# convert string timestamp to pandas time index     
dfs = [inflation, gdp, m2, fed_funds]
inflation, gdp, m2, fed_funds = [convert_date_column(df) for df in dfs]

# some preprocessing
fed_funds = convert_to_quarterly(fed_funds)
log_gdp, log_m2, log_ff = [np.log(df) for df in [gdp, m2, fed_funds]]

# join data
dfs = [inflation, log_gdp, log_m2, log_ff]
df_all = join_dfs_by_index(dfs)

# rename columns
colnames = ["inflation", "log_gdp", "log_m2", "log_ff"]
df_all.columns =  colnames
df_all.head()
# Out:
#             inflation   log_gdp    log_m2    log_ff
# DATE
# 1960-01-01        0.2  9.763075  6.922939  2.482404
# 1960-04-01        0.1  9.755741  6.923530  2.468100
# 1960-07-01        0.0  9.754001  6.936440  2.406044
# 1960-10-01        0.7  9.737315  6.947264  2.175887
# 1961-01-01        0.0  9.740145  6.959019  1.930071

# %% [markdown]
# ## Cheking for Trend and Stationarity
# Plotting all 4 time series to get a visual impression whether trend is present.

# %%
df_all.plot(subplots=True, figsize=(20,15))
plt.show()

# %% [markdown]
# The first three time series continuously growing. There seems to be no clear trend for the fed funds rate. On the other hand, this time series does not look stationary at all.

# %% [markdown]
# As a next step, we test for trend using the Augmented Dickey-Fuller Test.

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(x,colname):
    result = adfuller(x)
    print('ADF-Test Results for %s' % colname)
    print('Statistic: %f' % result[0])
    print('p-value: %f' % result[1])
    print('Critical Values:')
    for key, value in result[4].items():
        print('\t%s: %.3f' % (key, value))
        
[adf_test(df_all[col],col) for col in colnames]
# Out:
# ADF-Test Results for inflation
# Statistic: -1.307278
# p-value: 0.625836
# Critical Values:
# 	5%: -2.875
# 	1%: -3.461
# 	10%: -2.574
# ADF-Test Results for log_gdp
# Statistic: -2.083490
# p-value: 0.251205
# Critical Values:
# 	5%: -2.874
# 	1%: -3.459
# 	10%: -2.574
# ADF-Test Results for log_m2
# Statistic: -0.239533
# p-value: 0.933642
# Critical Values:
# 	5%: -2.874
# 	1%: -3.459
# 	10%: -2.574
# ADF-Test Results for log_ff
# Statistic: -2.061201
# p-value: 0.260399
# Critical Values:
# 	5%: -2.874
# 	1%: -3.459
# 	10%: -2.574
# [None, None, None, None]

# %% [markdown]
# All tests for each time series can not reject the $H_0$. Thus, we need to detrend each of them.

# %% [markdown]
# ## Detrending Inflation and Fed Funds
# Simplest Way: Take the first difference

# %%
df_fd = df_all.diff(axis=0)[1:]
df_fd.plot(subplots=True, figsize=(20,15))
plt.show()

# %%
[adf_test(df_fd[col],col) for col in df_fd]
# Out:
# ADF-Test Results for inflation
# Statistic: -6.890420
# p-value: 0.000000
# Critical Values:
# 	5%: -2.875
# 	1%: -3.461
# 	10%: -2.574
# ADF-Test Results for log_gdp
# Statistic: -7.407929
# p-value: 0.000000
# Critical Values:
# 	5%: -2.874
# 	1%: -3.459
# 	10%: -2.574
# ADF-Test Results for log_m2
# Statistic: -5.398130
# p-value: 0.000003
# Critical Values:
# 	5%: -2.874
# 	1%: -3.459
# 	10%: -2.574
# ADF-Test Results for log_ff
# Statistic: -5.784248
# p-value: 0.000001
# Critical Values:
# 	5%: -2.874
# 	1%: -3.459
# 	10%: -2.574
# [None, None, None, None]

# %% [markdown]
# After taking first difference, time series of the plot look more stationary. The Augmented-Dickey-Fuller Tests also reject the $H_0$ for every time series now. Thus, we going to use the first difference for now on. We also cut out the time frame where all time series look the most stationary.

# %%
df = df_fd
colnames = ["fd_inflation", "fd_log_gdp", "fd_log_m2", "fd_log__ff"]
df.columns = colnames
df.head()
df = df["1985-01-01":"2004-01-01"]
#df.plot(subplots=True,figsize=(20,15))
#plt.show()

# %% [markdown]
# ## Structural VAR Estimation
# Now we are going to use the converted times series to estimate a Structural Vectorautoregressive Model (SVAR), i.e.
#
# \begin{equation}
#     \mathbf{B}_0 \mathbf{Z}_t = \mathbf{c} + \mathbf{B_1} \mathbf{Z}_{t-1} + \dots + \mathbf{B_p} \mathbf{Z}_{t-p} + \mathbf{\epsilon}_t
# \end{equation}
#
# where
# \begin{equation*}
# \mathbf{Z}_t =  \begin{bmatrix}
#  \pi_t \\ \ln Y_t \\ \ln m_t \\ \ln R_t
# \end{bmatrix}
# \end{equation*}
#
# We are going to do this in two steps:
# - estimate a VAR(p) model
# - recover $B_0$ with recursive restriction or sign restriction

# %% [markdown]
# ### Estimating VAR(p)
# First we need to choose the optimal lag order of VAR(p)

# %%
from statsmodels.tsa.api import VAR
model = VAR(df)
model.select_order(10)
# Out:
#                  VAR Order Selection
# ======================================================
#             aic          bic          fpe         hqic
# ------------------------------------------------------
# 0        -27.17       -27.04    1.587e-12       -27.12
# 1        -28.07      -27.41*    6.479e-13       -27.81
# 2        -28.27       -27.08    5.336e-13       -27.80
# 3        -28.83       -27.12   3.070e-13*      -28.15*
# 4        -28.64       -26.40    3.832e-13       -27.75
# 5        -28.71       -25.95    3.699e-13       -27.62
# 6        -28.84       -25.55    3.468e-13       -27.54
# 7       -28.95*       -25.13    3.413e-13       -27.44
# 8        -28.68       -24.33    5.120e-13       -26.96
# 9        -28.68       -23.81    6.090e-13       -26.75
# 10       -28.74       -23.35    7.317e-13       -26.61
# ======================================================
# * Minimum
# {'aic': 7, 'bic': 1, 'fpe': 3, 'hqic': 3}

# %% [markdown]
# AIC and the final prediction error would choose 3 lags, while BIC and the Hannan-Quinn Information Criterium (HQIC) would choose 1 lag. We going to use 3 lags.

# %%
var_result = model.fit(maxlags=10, ic='aic')

# get model parameters
A = var_result.coefs # A_i = A[i-1]
U = var_result.resid
Sigma_U = var_result.sigma_u

# model summary
var_result.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 06, Feb, 2018
# Time:                     17:04:15
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                   -25.1181
# Nobs:                     70.0000    HQIC:                  -27.3641
# Log likelihood:           728.243    FPE:                3.67421e-13
# AIC:                     -28.8442    Det(Omega_mle):     9.18364e-14
# --------------------------------------------------------------------
# Results for equation fd_inflation
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                  -0.099454         0.050119           -1.984           0.054
# L1.fd_inflation        -0.820885         0.141568           -5.799           0.000
# L1.fd_log_gdp          -2.940993         3.987098           -0.738           0.465
# L1.fd_log_m2           -1.606167         2.844263           -0.565           0.575
# L1.fd_log__ff           0.075437         0.289872            0.260           0.796
# L2.fd_inflation        -0.477528         0.178141           -2.681           0.011
# L2.fd_log_gdp           2.562411         4.151743            0.617           0.541
# L2.fd_log_m2           -0.797869         2.806579           -0.284           0.778
# L2.fd_log__ff          -0.253872         0.317334           -0.800           0.428
# L3.fd_inflation        -0.711732         0.201315           -3.535           0.001
# L3.fd_log_gdp          -1.079281         4.427992           -0.244           0.809
# L3.fd_log_m2           -0.940626         2.839099           -0.331           0.742
# L3.fd_log__ff           0.210310         0.322194            0.653           0.518
# L4.fd_inflation        -0.331914         0.239483           -1.386           0.173
# L4.fd_log_gdp           4.090504         4.624836            0.884           0.382
# L4.fd_log_m2            1.578504         2.793713            0.565           0.575
# L4.fd_log__ff          -0.159656         0.328539           -0.486           0.630
# L5.fd_inflation        -0.290859         0.210183           -1.384           0.174
# L5.fd_log_gdp           1.994981         4.522705            0.441           0.661
# L5.fd_log_m2           -2.592474         2.787348           -0.930           0.358
# L5.fd_log__ff           0.615956         0.326498            1.887           0.066
# L6.fd_inflation        -0.632517         0.184438           -3.429           0.001
# L6.fd_log_gdp           0.681963         4.443699            0.153           0.879
# L6.fd_log_m2            7.074270         2.871698            2.463           0.018
# L6.fd_log__ff           0.599147         0.329055            1.821           0.076
# L7.fd_inflation        -0.417974         0.132957           -3.144           0.003
# L7.fd_log_gdp           5.609063         4.642158            1.208           0.234
# L7.fd_log_m2            1.236108         3.002379            0.412           0.683
# L7.fd_log__ff          -0.376662         0.258705           -1.456           0.153
# ==================================================================================
#
# Results for equation fd_log_gdp
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.002219         0.002029            1.094           0.280
# L1.fd_inflation        -0.005039         0.005730           -0.879           0.384
# L1.fd_log_gdp           0.137529         0.161376            0.852           0.399
# L1.fd_log_m2           -0.005065         0.115120           -0.044           0.965
# L1.fd_log__ff           0.007401         0.011732            0.631           0.532
# L2.fd_inflation        -0.012162         0.007210           -1.687           0.099
# L2.fd_log_gdp           0.220137         0.168040            1.310           0.197
# L2.fd_log_m2           -0.054994         0.113595           -0.484           0.631
# L2.fd_log__ff          -0.000277         0.012844           -0.022           0.983
# L3.fd_inflation        -0.023034         0.008148           -2.827           0.007
# L3.fd_log_gdp          -0.253998         0.179221           -1.417           0.164
# L3.fd_log_m2            0.129180         0.114911            1.124           0.267
# L3.fd_log__ff           0.008898         0.013041            0.682           0.499
# L4.fd_inflation        -0.017813         0.009693           -1.838           0.073
# L4.fd_log_gdp           0.152002         0.187188            0.812           0.421
# L4.fd_log_m2            0.066911         0.113074            0.592           0.557
# L4.fd_log__ff           0.007121         0.013297            0.536           0.595
# L5.fd_inflation        -0.013343         0.008507           -1.568           0.124
# L5.fd_log_gdp           0.090479         0.183054            0.494           0.624
# L5.fd_log_m2           -0.060108         0.112816           -0.533           0.597
# L5.fd_log__ff          -0.007643         0.013215           -0.578           0.566
# L6.fd_inflation        -0.004432         0.007465           -0.594           0.556
# L6.fd_log_gdp          -0.120945         0.179856           -0.672           0.505
# L6.fd_log_m2            0.078723         0.116230            0.677           0.502
# L6.fd_log__ff           0.000078         0.013318            0.006           0.995
# L7.fd_inflation         0.003846         0.005381            0.715           0.479
# L7.fd_log_gdp           0.122504         0.187889            0.652           0.518
# L7.fd_log_m2            0.009438         0.121520            0.078           0.938
# L7.fd_log__ff           0.003397         0.010471            0.324           0.747
# ==================================================================================
#
# Results for equation fd_log_m2
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.001286         0.003043            0.423           0.675
# L1.fd_inflation        -0.014180         0.008596           -1.650           0.107
# L1.fd_log_gdp          -0.537281         0.242082           -2.219           0.032
# L1.fd_log_m2            0.257832         0.172693            1.493           0.143
# L1.fd_log__ff           0.005136         0.017600            0.292           0.772
# L2.fd_inflation        -0.020104         0.010816           -1.859           0.070
# L2.fd_log_gdp          -0.271940         0.252079           -1.079           0.287
# L2.fd_log_m2            0.138876         0.170405            0.815           0.420
# L2.fd_log__ff          -0.004403         0.019267           -0.228           0.820
# L3.fd_inflation        -0.017876         0.012223           -1.462           0.151
# L3.fd_log_gdp           0.256799         0.268851            0.955           0.345
# L3.fd_log_m2            0.165502         0.172380            0.960           0.343
# L3.fd_log__ff           0.019498         0.019562            0.997           0.325
# L4.fd_inflation        -0.016913         0.014541           -1.163           0.251
# L4.fd_log_gdp           0.111273         0.280803            0.396           0.694
# L4.fd_log_m2           -0.032669         0.169624           -0.193           0.848
# L4.fd_log__ff           0.015009         0.019948            0.752           0.456
# L5.fd_inflation        -0.008220         0.012762           -0.644           0.523
# L5.fd_log_gdp          -0.051228         0.274602           -0.187           0.853
# L5.fd_log_m2            0.117811         0.169238            0.696           0.490
# L5.fd_log__ff          -0.011325         0.019824           -0.571           0.571
# L6.fd_inflation        -0.003855         0.011198           -0.344           0.732
# L6.fd_log_gdp           0.245728         0.269805            0.911           0.368
# L6.fd_log_m2            0.088726         0.174359            0.509           0.614
# L6.fd_log__ff          -0.006250         0.019979           -0.313           0.756
# L7.fd_inflation        -0.002373         0.008073           -0.294           0.770
# L7.fd_log_gdp          -0.022487         0.281855           -0.080           0.937
# L7.fd_log_m2            0.228039         0.182293            1.251           0.218
# L7.fd_log__ff           0.023471         0.015708            1.494           0.143
# ==================================================================================
#
# Results for equation fd_log__ff
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                  -0.072335         0.027431           -2.637           0.012
# L1.fd_inflation         0.088754         0.077483            1.145           0.259
# L1.fd_log_gdp           6.279716         2.182217            2.878           0.006
# L1.fd_log_m2           -3.034596         1.556721           -1.949           0.058
# L1.fd_log__ff           0.488843         0.158653            3.081           0.004
# L2.fd_inflation         0.060030         0.097500            0.616           0.542
# L2.fd_log_gdp           5.536182         2.272331            2.436           0.019
# L2.fd_log_m2            2.102307         1.536096            1.369           0.179
# L2.fd_log__ff          -0.087930         0.173683           -0.506           0.615
# L3.fd_inflation         0.157359         0.110184            1.428           0.161
# L3.fd_log_gdp          -0.243624         2.423527           -0.101           0.920
# L3.fd_log_m2           -0.574090         1.553895           -0.369           0.714
# L3.fd_log__ff           0.122197         0.176343            0.693           0.492
# L4.fd_inflation         0.195269         0.131074            1.490           0.144
# L4.fd_log_gdp           2.233993         2.531264            0.883           0.383
# L4.fd_log_m2            0.998889         1.529054            0.653           0.517
# L4.fd_log__ff          -0.281162         0.179816           -1.564           0.126
# L5.fd_inflation         0.155900         0.115038            1.355           0.183
# L5.fd_log_gdp           1.780132         2.475365            0.719           0.476
# L5.fd_log_m2           -3.515418         1.525570           -2.304           0.026
# L5.fd_log__ff          -0.046074         0.178699           -0.258           0.798
# L6.fd_inflation         0.211949         0.100947            2.100           0.042
# L6.fd_log_gdp           2.518224         2.432124            1.035           0.307
# L6.fd_log_m2            2.408286         1.571737            1.532           0.133
# L6.fd_log__ff          -0.060216         0.180098           -0.334           0.740
# L7.fd_inflation         0.152956         0.072770            2.102           0.042
# L7.fd_log_gdp          -1.658874         2.540744           -0.653           0.517
# L7.fd_log_m2           -3.266621         1.643261           -1.988           0.054
# L7.fd_log__ff          -0.054659         0.141594           -0.386           0.701
# ==================================================================================
#
# Correlation matrix of residuals
#                 fd_inflation  fd_log_gdp  fd_log_m2  fd_log__ff
# fd_inflation        1.000000   -0.243165  -0.267862    0.242933
# fd_log_gdp         -0.243165    1.000000   0.211918   -0.163579
# fd_log_m2          -0.267862    0.211918   1.000000   -0.426483
# fd_log__ff          0.242933   -0.163579  -0.426483    1.000000

# %% [markdown]
# ### Recursive Restrictions using Cholesky Decomposition
#
# \begin{equation*}
# \mathbf{B}_0 =  \begin{bmatrix}
#  b_{11}  & 0       & 0        & 0 \\
#  b_{21}  & b_{22}  & 0        & 0 \\
#  b_{31}  & b_{32}  & b_{33}   & 0 \\
#  b_{41}  & b_{42}  & b_{43}   & b_{44}
# \end{bmatrix}
# \end{equation*}
#
# Note that the order of the variable in $Z_t$ in the estimated VAR matters, since it determines the restrictions.
#
# \begin{equation*}
# \mathbf{Z}_t =  \begin{bmatrix}
#  \pi_t \\ \ln Y_t \\ \ln m_t \\ \ln R_t
# \end{bmatrix}
# \end{equation*}
#
# We have choosen the same order as in Kilian & Lüktepohl (2017, chapter 8.4). According to them, with the restrictions in $\mathbf{B}_0$ with the order in $\mathbf{Z}_t$ the equations in resulting SVAR can be interpreted as follow:
# * first equation: horizontal aggregate supply (AS) curve
# * second equation: a downward-sloping aggregate demand (AD) curve
# * third equation: as money demand
# * fourth equation: as monetary policy reaction function

# %% [markdown]
# Let get $\mathbf{B}_0 = \mathbf{P}^{-1}$ where $\mathbf{\Sigma}_U = \mathbf{P}\mathbf{P}^T$

# %%
P = np.linalg.cholesky(Sigma_U) 
B_0 = np.linalg.inv(P)

# %% [markdown]
# Now lets compute impulse responses and  plot them. Although Statsmodels already provides a function to plot the IRF, we can not use it, because it only works for ordinary VAR(p). Thus, I have written som function to compute and plot the irf myself. The following functions as their name implies. First we transform the VAR into the companion form using get_companion_matrix(). Next, the get_reduced_form_ir() function computes $\mathbf{\Phi_i} = \mathbf{J} \mathbf{A}^i \mathbf{J}$ for a given horizon i where $\mathbf{J} = [\mathbf{I_k},\mathbf{0}_{k \times k(p-1)}]$. For each horizon $i = 1,\dots,h$ we then compute $\mathbf{\Theta}_i = \mathbf{\Phi}_{i} \mathbf{B}_{0}^{-1}$ and store all $h$- result into an h-dimensional np.array. finally, the function plot_struc_irf plot the resulting irf.

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_struc_irf(df,Theta,shock_in,horizon=10):
    """
    Returns IRF plots given a shock in a variable specifiied in shock_in
    """
    j = df.columns.get_loc(shock_in)
    plt.figure(1,figsize=(20,10))
    plt.suptitle("IRF for shocks in " + shock_in, fontsize=30)
    for i in range(0,df.shape[1]):
        irf = np.zeros((horizon+1,1))
        if (i == j):
            irf[0] = 1
        for h in range(0,horizon):
            irf[h+1] = Theta[:][h][j][i]
        plt.subplot(221 + i)
        plt.title("Effect on " + df.columns[i] + " given shock in " + shock_in)
        plt.plot(range(0,horizon+1), irf, color='b', linewidth=2.0)

def get_struct_ir(coefs,B_0,last_horizon):
    """
    Return all structural impulse responses given VAR(p) coefficients and B_0
    for number h = 1,..., last_horizon
    Result in a 3-dimensional array Theta of dimension (last_horizon,k,k)
    containing all impulse repsonses Theta_i for given horizon i 
    """
    p, k, k2 = coefs.shape
    assert(k == k2)
    A_companion = get_companion_matrix(coefs,p,k) 
    Theta = np.zeros((last_horizon,k,k))
    for i in range(0,last_horizon):
        Phi_i = get_reduced_form_ir(A_companion,p,k,i)
        if (i == 0):
            Theta_i = np.linalg.inv(B_0)
        else:
            Theta_i = np.dot(Phi_i,np.linalg.inv(B_0))
        Theta[i] = Theta_i
    return Theta


def get_reduced_form_ir(A_companion,p,k,horizon):
    """
    Return Reduce form impuls response
    Phi_i = J A^i J where i is the horizon and J := [I_k, 0_kxk(p-1)]
    """
    identity_k = np.identity(k)
    zeros_k_pk = np.zeros((k,k*(p-1)))
    J = np.concatenate((identity_k, zeros_k_pk), axis=1)
    Phi = np.dot(J,np.dot(A_companion**horizon,J.T))
    return Phi
    
def get_companion_matrix(coefs, k, p):
    """
    Return compansion matrix for the VAR(1) representation for a VAR(p) process
    (companion form)
    A = [A_1 A_2 ... A_p-1 A_p
         I_K 0       0     0
         0   I_K ... 0     0
         0 ...       I_K   0]
    """
    p, k, k2 = coefs.shape
    assert(k == k2)

    kp = k * p

    result = np.zeros((kp, kp))
    result[:k] = np.concatenate(coefs, axis=1)

    # Set I_K matrices
    if p > 1:
        result[np.arange(k, kp), np.arange(kp-k)] = 1

    return result

Theta = get_struct_ir(A,B_0,last_horizon=10)
plot_struc_irf(df,Theta,shock_in="fd_log_m2",horizon=10)
plt.show()

# %%
plot_struc_irf(df,Theta,shock_in="fd_inflation",horizon=10)
plt.show()

# %% [markdown]
# ### Sign Restrictions
# Ideas for sign restriction:
# * (inflation,GDP) --> + (phillips curve)  $b_{12} = +$
# * (m2,inflation) --> + $b_{3,1} = +$
# * (ff, m2) - --> ff up, m2 down $b_{4,3} = -$
# * (inflation,ff) + --> inflation up, ff goes up $b_{1,4}=+$
#
# Thus we get
#
# \begin{equation*}
# \mathbf{B}_0 =  \begin{bmatrix}
#  b_{11}       & +  & b_{13}  & + \\
#  b_{21}  & b_{22}  & b_{2,3} & b_{2,4} \\
#  +       & b_{32} & b_{33}   & b_{3,4} \\
#  b_{41} & b_{42}  & -        & b_{44}
# \end{bmatrix}
# \end{equation*}
#
# In order to implement sign restriction, we use the algorithm proposed in Ramirez et al. (2010).

# %%
def generate_gaussian_matrix(k):
    mu, sigma = 0, 1
    W = np.empty((k,k))
    for i in range(0,k):
        W[i] = np.random.normal(mu, sigma, k)
    return W

def qr_with_positive_diagonals(W):
    Q, R  = np.linalg.qr(W)
    R_diag = np.diagonal(R)
    for i in range(0,Q.shape[0]):
        if (R_diag[i] < 0):
            Q[i][i] *= -1
    return Q

def satisfies_restrictions(candidate, restrictions):
    restrictions_fulfilled = True
    for restriction in restrictions:
        i, j = restriction[0]
        element_to_check = B_0[i][j]
        if (np.sign(element_to_check) != np.sign(restriction[1])):
            restrictions_fulfilled = False
    return restrictions_fulfilled

restrictions = np.array([[(0,1),1],[(0,3),1],[(2,0),1],[(3,2),-1]])
restrictions_fulfilled = False
counter = 0
while (restrictions_fulfilled is False):
    counter += 1
    W = generate_gaussian_matrix(4)
    Q = qr_with_positive_diagonals(W)
    P = cholesky(Sigma_U, lower=True) 
    B_0 = P.dot(Q)
    restrictions_fulfilled = satisfies_restrictions(B_0,restrictions)
    print('Iteration %i' % counter)
print B_0
# Out:
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Iteration 6
# Iteration 7
# Iteration 8
# Iteration 9
# Iteration 10
# Iteration 11
# Iteration 12
# [[-0.05212785  0.01017294 -0.09718164  0.11358011]
#  [ 0.00199665 -0.00133197  0.0036632   0.00239929]
#  [ 0.00027023 -0.00765488  0.0034603  -0.00198742]
#  [ 0.05839959  0.01993213 -0.04382721  0.00561334]]

# %%
Theta = get_struct_ir(A,B_0,last_horizon=10)
plot_struc_irf(df,Theta,shock_in="fd_log_m2",horizon=10)
plt.show()

# %%
plot_struc_irf(df,Theta,shock_in="fd_inflation",horizon=10)
plt.show()

# %% [markdown]
# IRF for shock in inflation is completly determined by the sign restrictions
